# %%
import re
import requests
import bs4 as bs

from utils import *

# %%
page_link = 'https://ziparchive.download/anime/devilman-crybaby'
prefix = 'https://ziparchive.download/'
all_links = extract_page_links(page_link)
print_array([prefix + suffix for suffix in all_links])
# Out:
# https://ziparchive.download//dl/3/27usjtcham4ox95y0r8g3iv1qwdplfkezb6
# https://ziparchive.download//dl/1/ycg24e5ihtmpdwfoals97bvzqxnuj0k316r
# https://ziparchive.download//dl/2/ml94y708vsezaj12kdgchfx5pwit3oqbr6u
# https://ziparchive.download//anime/mirai-nikki-bd
# https://ziparchive.download//dl/1/lp1dcb6je8ra3xyqmo0zw9f5h2ung4s7kiv
# https://ziparchive.download/#
# https://ziparchive.download/https://plus.google.com/share?url=https://ziparchive.download/anime/devilman-crybaby
# https://ziparchive.download//dl/1/z0r2917yinbkpoag3jxwsve4c6h5umtdlqf
# https://ziparchive.download//pages/request-upload
# https://ziparchive.download//anime-genre/dementia
# https://ziparchive.download/https://disqus.com/?ref_noscript
# https://ziparchive.download//dl/2/bhvsuypzf95ra1xin48jkt3g62de0lmqw7o
# https://ziparchive.download//dl/2/6sr52nahjv4fuydq19eczgtl03pw8b7ikxo
# https://ziparchive.download/http://www.facebook.com/sharer/sharer.php?u=https://ziparchive.download/anime/devilman-crybaby
# https://ziparchive.download//anime/re-zero-kara-hajimeru-isekai-seikats-bd
# https://ziparchive.download//
# https://ziparchive.download//anime-genre/supernatural
# https://ziparchive.download//list/anime
# https://ziparchive.download/https://trav4life.site/ad_d.php?u=NTg0
# https://ziparchive.download//dl/3/bixg12eht0n89k3m7lscfjapu5qvo6rw4yd
# https://ziparchive.download//dl/3/ra1jkxfpem6yo8qwst9n3zubhvi0d7c524g
# https://ziparchive.download//dl/3/49dh2xefvbtnjyo87rl1ksw6g5mq0zcu3pa
# https://ziparchive.download//dl/3/78pdbrxka3vfymn0zcqew6it2ouljs4h519
# https://ziparchive.download//recommendation/anime
# https://ziparchive.download/#
# https://ziparchive.download//anime/death-parade
# https://ziparchive.download//dl/1/7sryvaezqidb95o12ng68j4lfputk3xc0hw
# https://ziparchive.download//anime-genre/demons
# https://ziparchive.download//dl/3/xuyhcpqrj53mzvitdaf86ok70sneb42lw9g
# https://ziparchive.download/#
# https://ziparchive.download/#
# https://ziparchive.download//pages/tutorial-how-to-download
# https://ziparchive.download//anime/death-note-bd
# https://ziparchive.download//anime-genre/horror
# https://ziparchive.download//anime/zankyou-no-terror
# https://ziparchive.download//anime/kagewani
# https://ziparchive.download//dl/1/nxl7pgc9wi3aeq15sufz680m2djorvbthk4
# https://ziparchive.download//dl/2/oi8y4sr1hp95nkfq67gd03bvtalcmwezx2j
# https://ziparchive.download//anime/b-the-beginning
# https://ziparchive.download//dl/1/xv3smebrtaqlkgp2019hydi5ozfnw8c47ju
# https://ziparchive.download//pages/report-dead-link
# https://ziparchive.download//anime/another-bd
# https://ziparchive.download//dl/2/z9lhtipvdx6uc0bnjokmqw54g2r7afy13e8
# https://ziparchive.download//anime-genre
# https://ziparchive.download//anime/steins-gate
# https://ziparchive.download//anime/ga-rei-zero
# https://ziparchive.download/http://twitter.com/share?url=https://ziparchive.download/anime/devilman-crybaby&text=Devilman: Crybaby, Read More :
# https://ziparchive.download//
# https://ziparchive.download//dl/2/t742mqi9yzudbr5po8aknj3vw6gle0sc1fx
# https://ziparchive.download//anime-genre/action

# %%
pattern = '^/dl/\d+/'
download_links = [string for string in all_links if re.search(pattern,string)]
print_array([prefix + sufix for sufix in download_links])
# Out:
# https://ziparchive.download//dl/3/27usjtcham4ox95y0r8g3iv1qwdplfkezb6
# https://ziparchive.download//dl/1/ycg24e5ihtmpdwfoals97bvzqxnuj0k316r
# https://ziparchive.download//dl/2/ml94y708vsezaj12kdgchfx5pwit3oqbr6u
# https://ziparchive.download//dl/1/lp1dcb6je8ra3xyqmo0zw9f5h2ung4s7kiv
# https://ziparchive.download//dl/1/z0r2917yinbkpoag3jxwsve4c6h5umtdlqf
# https://ziparchive.download//dl/2/bhvsuypzf95ra1xin48jkt3g62de0lmqw7o
# https://ziparchive.download//dl/2/6sr52nahjv4fuydq19eczgtl03pw8b7ikxo
# https://ziparchive.download//dl/3/bixg12eht0n89k3m7lscfjapu5qvo6rw4yd
# https://ziparchive.download//dl/3/ra1jkxfpem6yo8qwst9n3zubhvi0d7c524g
# https://ziparchive.download//dl/3/49dh2xefvbtnjyo87rl1ksw6g5mq0zcu3pa
# https://ziparchive.download//dl/3/78pdbrxka3vfymn0zcqew6it2ouljs4h519
# https://ziparchive.download//dl/1/7sryvaezqidb95o12ng68j4lfputk3xc0hw
# https://ziparchive.download//dl/3/xuyhcpqrj53mzvitdaf86ok70sneb42lw9g
# https://ziparchive.download//dl/1/nxl7pgc9wi3aeq15sufz680m2djorvbthk4
# https://ziparchive.download//dl/2/oi8y4sr1hp95nkfq67gd03bvtalcmwezx2j
# https://ziparchive.download//dl/1/xv3smebrtaqlkgp2019hydi5ozfnw8c47ju
# https://ziparchive.download//dl/2/z9lhtipvdx6uc0bnjokmqw54g2r7afy13e8
# https://ziparchive.download//dl/2/t742mqi9yzudbr5po8aknj3vw6gle0sc1fx

# %%
link = 'https://ziparchive.download/link-locked/duxol1tp7ewy2rm'
response = requests.get(link,timeout=5)
content = bs.BeautifulSoup(response.content,'html.parser')

# %%
print(content)
# Out:
# <!DOCTYPE html>
#
# <html lang="en-US" prefix="og: http://ogp.me/ns#">
# <head>
# <title>Link Locked Download Devilman: Crybaby Episode 10 720p Subtitle English Using File Host Uptobox - Zip Archive</title>
# <!--
#         <link rel="apple-touch-icon" href="#">
# 		<link rel="shortcut icon" type="image/png" href="#"/>
#         -->
# <meta charset="utf-8"/>
# <meta content="#151414" name="theme-color">
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="/config/css/bootstrap.min.css" rel="stylesheet"/>
# <link href="/config/css/fontawesome-all.min.css" rel="stylesheet"/>
# <link href="/main.css" rel="stylesheet" type="text/css"/>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/jquery/3.3.1/jquery.min.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/twitter-bootstrap/4.1.1/js/bootstrap.min.js"></script>
# <meta content="a7f50d6574c99a6e3d79ce1825590153" name="hitads">
# <style type="text/css">
# 		body {
# 		    color: #d4d4d4;
# 		}
# 		</style>
# </meta></meta></head>
# <!-- Page Content -->
# <div class="container">
# <div class="row">
# <div class="col-md-2"></div>
# <div class="col-md-8">
# <!-- Blog Post -->
# <div class="card mb-4">
# <h5 class="card-header"><i class="fas fa-lock"></i> Link Locked</h5>
# <div class="card-body">
# <p class="card-text" style="text-align:center;">
# <a href="https://trav4life.site/ad_d.php?u=NTg0">
# <img src="https://ziparchive.download/post-image/download-button3-1172.gif" width="200"/>
# </a>
# <br/>
# 					====== Request File Info ======<br>
# 					Anime = Devilman: Crybaby <br/>Name File = Episode 10 <br/>Res. = 720p <br/>Subtitle = English <br/>File Host = Uptobox <br/>					================================<br/>
# <!-- Composite Start -->
# <div id="M363372ScriptRootC277127">
# <div id="M363372PreloadC277127">
#         Loading...    </div>
# <script>
#                 (function(){
#             var D=new Date(),d=document,b='body',ce='createElement',ac='appendChild',st='style',ds='display',n='none',gi='getElementById',lp=d.location.protocol,wp=lp.indexOf('http')==0?lp:'https:';
#             var i=d[ce]('iframe');i[st][ds]=n;d[gi]("M363372ScriptRootC277127")[ac](i);try{var iw=i.contentWindow.document;iw.open();iw.writeln("<ht"+"ml><bo"+"dy></bo"+"dy></ht"+"ml>");iw.close();var c=iw[b];}
#             catch(e){var iw=d;var c=d[gi]("M363372ScriptRootC277127");}var dv=iw[ce]('div');dv.id="MG_ID";dv[st][ds]=n;dv.innerHTML=277127;c[ac](dv);
#             var s=iw[ce]('script');s.async='async';s.defer='defer';s.charset='utf-8';s.src=wp+"//jsc.mgid.com/z/i/ziparchive.download.277127.js?t="+D.getYear()+D.getMonth()+D.getUTCDate()+D.getUTCHours();c[ac](s);})();
#     </script>
# </div>
# <!-- Composite End -->
# <center>
# <br/>
# <a class="badge badge-pill badge-success" href="https://ziparchive.download/openlink/3/3v1tki4cl6bju85enwd2hr9gas7mqxo0fzp" target="_blank">Click here to Download</a>
# <br/>
# <br/>
# <a href="https://trav4life.site/ad_d.php?u=NTg0">
# <img src="https://ziparchive.download/post-image/download-button3-1172.gif" width="200"/>
# </a>
# <br/>
# </center>
# <br><br><br/>
# </br></br></br></p>
# </div>
# </div>
# </div>
# <div class="col-md-2"></div>
# </div>
# </div>
# <!-- /.container -->
# <script src="//hitsmedia.us/ad_onclick.php?u=NTg1" type="text/javascript"></script>
# <!-- PopAds.net Popunder Code for ziparchive.download | 2018-05-16,2641058,0,0 -->
# <script data-cfasync="false" type="text/javascript">
# /*<![CDATA[/* */
# /* Privet darkv. Each domain is 2h fox dead */
#  (function(){ var a=window;a["\u005f\x70\u006f\x70"]=[["s\u0069\u0074\u0065\x49\u0064",2641058],["m\u0069\x6e\u0042\x69\u0064",0],["po\x70un\x64\x65r\x73\u0050\x65\x72\u0049\x50",0],["\u0064\x65\u006ca\u0079\x42e\x74we\x65\u006e",0],["\u0064\u0065\u0066\x61u\x6c\u0074",false],["d\x65\u0066\u0061\x75\u006c\x74\x50\u0065\x72D\u0061\x79",0],["t\x6fp\x6dostLa\u0079\u0065\u0072",!0]];var o=["//c\u0031\u002e\u0070\u006f\x70a\u0064\x73\u002e\u006e\u0065\u0074\x2fpo\x70\u002e\x6a\u0073","/\u002fc\u0032\x2ep\x6f\u0070\x61\u0064\x73\x2e\u006e\u0065t/\u0070\u006f\x70.\u006as","\x2f/\u0077\u0077\u0077\x2ef\u006d\x62\x6a\x78\x71v\u006bj\x66\u006d\u006a\u002e\u0063\u006f\u006d\u002fx.\x6as","/\u002f\x77\u0077\u0077.\x62\u0069hz\x71\u0064\u0066\u006c\u0078eel\u0063.\u0063\x6f\u006d\u002fe\x72\x6c\x2e\u006a\x73",""],g=0,k,m=function(){if(""==o[g])return;k=a["\u0064o\x63\u0075m\x65n\x74"]["\u0063r\x65\u0061t\u0065\x45\x6ce\u006de\x6et"]("\x73c\u0072i\u0070\u0074");k["\u0074\u0079pe"]="\x74\x65x\u0074\u002f\u006aav\u0061\x73\x63\x72\u0069\u0070t";k["\x61s\x79\u006e\u0063"]=!0;var c=a["\x64\x6fcu\x6d\x65n\x74"]["\u0067e\x74\x45l\x65me\x6e\u0074sB\x79\x54a\x67\u004e\x61\u006de"]("sc\u0072\x69\u0070\x74")[0];k["\x73rc"]=o[g];if(g<2){k["c\u0072o\x73s\x4f\x72\x69\x67\x69n"]="\x61\u006e\u006f\x6ey\x6d\u006f\x75\u0073";};k["\x6fnerr\u006fr"]=function(){g++;m()};c["pa\u0072\x65\x6et\x4e\u006f\u0064e"]["\u0069\x6e\x73\u0065\u0072\u0074\u0042\x65\x66\x6fr\u0065"](k,c)};m()})();
# /*]]>/* */
# </script>
