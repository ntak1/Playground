# %% [markdown]
# # Let's use some graph algorithms to navigate though Wikipedia!
# Nothing like a soup made of nice data structures and algorithms!

# %%
from bs4 import BeautifulSoup
import requests
import time
from random import shuffle

from utils import *

# %% [markdown]
# ---
# First, let's define some basic data structures.
# * Stack:it might be seen as a list that follows the idea "last in first out"
# * Queue: it might be seen as a list that follows the idea "first in first out"

# %%
# Defining basic data structures
class List:
    def __init__(self):
        self.items = []
        
    def isEmpty(self):
         return self.items == []
        
    def size(self):
         return len(self.items)
        
    def print_items(self):
        print(self.items)

class Stack(List):
    def __init__(self):
        List.__init__(self)
        
    def push(self, item):
        self.items.append(item)

    def pop(self):
        return self.items.pop()

    def peek(self):
        return self.items[len(self.items)-1]
        
class Queue(List):    
    def __init__(self):
        List.__init__(self)
    
    def enqueue(self, item):
        self.items.append(item)
    
    def dequeue(self):
        item = self.items[0]
        del self.items[0]
        return item

# %% [markdown]
# ### Two of the most basic graph algorithms
# See references:
# [[1]BFS - portuguese](https://www.ime.usp.br/~pf/algoritmos_para_grafos/aulas/bfs.html)
# [[2]DFS - portuguese](https://www.ime.usp.br/~pf/algoritmos_para_grafos/aulas/dfs.html)

# %%
# The basic walking on graphs algorithms
def dfs_iteratitve(v, visited_nodes, end_node, filters=None):
    if not None:
        contain, not_contain = filters
    s = Stack()
    s.push(v)
    i = 0
    while s.size() > 0 and i < 10000:
        v = s.pop()
        i += 1
        print('Iteration:', i)
        visited = False
        for string in visited_nodes:
            if  v in string:
                visited = True
        if not visited:
            print('\t', v)
            print('\t','https://en.wikipedia.org/'+ v,'\n------------------------------')
            visited_nodes.append(v)
            try:
                v_adj_links = extract_page_links(v)
                time.sleep(0.01)
            except:
                continue
            for w in v_adj_links:
                if end_node in w:
                    print('Over!!!!')
                    print('\t','https://en.wikipedia.org/'+ w,'\n------------------------------')
                    return
                s.push(w)
        if i%100 == 0:
            print(visited_nodes)
    print(s.size())
    return None

def bfs_iterative(v, visited_nodes, end_node, filters=None):
    if not None:
        contain, not_contain = filters
    q = Queue()
    q.enqueue(v)
    i = 0
    while q.size() > 0 and i < 10000:
        v = q.dequeue()
        i += 1
        print('Iteration:', i)
        visited = False
        for string in visited_nodes:
            if  v in string:
                visited = True
        if not visited:
            print('\t', v)
            print('\t','https://en.wikipedia.org/'+ v,'\n------------------------------')
            visited_nodes.append(v)
            try:
                v_adj_links = extract_page_links(v)
                time.sleep(0.01)
            except:
                continue
            for w in v_adj_links:
                if end_node in w:
                    print('Over!!!!')
                    print('\t','https://en.wikipedia.org/'+ w,'\n------------------------------')
                    return
                q.enqueue(w)
        if i%100 == 0:
            print(visited_nodes)
    print(q.size())
    return None

# %% [markdown]
# ### Define the filters for the links

# %%
contain = ['/wiki/']
not_contain = ['Wikipedia:', 'About:', 'File:', 'Contact']
filters = (contain, not_contain)

# %% [markdown]
# ### BFS

# %%
visited_nodes = []
end_node =_node = 'wiki/China'
initial_node = 'wiki/March_Comes_in_like_a_Lion'
bfs_iterative(initial_node, visited_nodes, end_node, filters)
# Out:
# Iteration: 1
# 	 wiki/March_Comes_in_like_a_Lion
# 	 https://en.wikipedia.org/wiki/March_Comes_in_like_a_Lion
# ------------------------------
# Iteration: 2
# 	 /wiki/Help:Category
# 	 https://en.wikipedia.org//wiki/Help:Category
# ------------------------------
# Iteration: 3
# 	 /wiki/Category:Shaft_(company)
# 	 https://en.wikipedia.org//wiki/Category:Shaft_(company)
# ------------------------------
# Iteration: 4
# 	 #cite_note-DubCast-10
# 	 https://en.wikipedia.org/#cite_note-DubCast-10
# ------------------------------
# Iteration: 5
# 	 /wiki/Hakusensha
# 	 https://en.wikipedia.org//wiki/Hakusensha
# ------------------------------
# Iteration: 6
# 	 /wiki/Katte_ni_Kaiz%C5%8D
# 	 https://en.wikipedia.org//wiki/Katte_ni_Kaiz%C5%8D
# ------------------------------
# Iteration: 7
# 	 /wiki/Special:MyContributions
# 	 https://en.wikipedia.org//wiki/Special:MyContributions
# ------------------------------
# Iteration: 8
# 	 http://www.animenewsnetwork.com/news/2007-06-22/honey-and-clover's-chika-umino's-latest-to-start-july-13
# 	 https://en.wikipedia.org/http://www.animenewsnetwork.com/news/2007-06-22/honey-and-clover's-chika-umino's-latest-to-start-july-13
# ------------------------------
# Iteration: 9
# 	 /wiki/Template_talk:Kodansha_Manga_Award_-_General
# 	 https://en.wikipedia.org//wiki/Template_talk:Kodansha_Manga_Award_-_General
# ------------------------------
# Iteration: 10
# 	 /wiki/Hidamari_Sketch
# 	 https://en.wikipedia.org//wiki/Hidamari_Sketch
# ------------------------------
# Iteration: 11
# 	 /wiki/Akiyuki_Shinbo
# 	 https://en.wikipedia.org//wiki/Akiyuki_Shinbo
# ------------------------------
# Iteration: 12
# 	 #cite_ref-31
# 	 https://en.wikipedia.org/#cite_ref-31
# ------------------------------
# Iteration: 13
# 	 #cite_ref-22
# 	 https://en.wikipedia.org/#cite_ref-22
# ------------------------------
# Iteration: 14
# 	 /wiki/Template_talk:Tezuka_Osamu_Cultural_Prize
# 	 https://en.wikipedia.org//wiki/Template_talk:Tezuka_Osamu_Cultural_Prize
# ------------------------------
# Iteration: 15
# 	 /wiki/Hideaki_Ito
# 	 https://en.wikipedia.org//wiki/Hideaki_Ito
# ------------------------------
# Iteration: 16
# 	 /wiki/Denpa_Onna_to_Seishun_Otoko
# 	 https://en.wikipedia.org//wiki/Denpa_Onna_to_Seishun_Otoko
# ------------------------------
# Iteration: 17
# 	 /wiki/Risa_It%C5%8D
# 	 https://en.wikipedia.org//wiki/Risa_It%C5%8D
# ------------------------------
# Iteration: 18
# 	 /wiki/Hurricane_Polymar
# 	 https://en.wikipedia.org//wiki/Hurricane_Polymar
# ------------------------------
# Iteration: 19
# 	 /wiki/Mari_Yamazaki
# 	 https://en.wikipedia.org//wiki/Mari_Yamazaki
# ------------------------------
# Iteration: 20
# 	 /wiki/Pani_Poni
# 	 https://en.wikipedia.org//wiki/Pani_Poni
# ------------------------------
# Iteration: 21
# 	 /wiki/Keith_Silverstein
# 	 https://en.wikipedia.org//wiki/Keith_Silverstein
# ------------------------------
# Iteration: 22
# 	 #cite_note-OctPremiere-8
# 	 https://en.wikipedia.org/#cite_note-OctPremiere-8
# ------------------------------
# Iteration: 23
# 	 #cite_ref-37
# 	 https://en.wikipedia.org/#cite_ref-37
# ------------------------------
# Iteration: 24
# 	 /wiki/Nisekoi
# 	 https://en.wikipedia.org//wiki/Nisekoi
# ------------------------------
# Iteration: 25
# 	 #Characters
# 	 https://en.wikipedia.org/#Characters
# ------------------------------
# Iteration: 26
# 	 /wiki/Maria_Holic
# 	 https://en.wikipedia.org//wiki/Maria_Holic
# ------------------------------
# Iteration: 27
# 	 #cite_note-24
# 	 https://en.wikipedia.org/#cite_note-24
# ------------------------------
# Iteration: 28
# 	 /wiki/Kino%27s_Journey
# 	 https://en.wikipedia.org//wiki/Kino%27s_Journey
# ------------------------------
# Iteration: 29
# 	 /wiki/Fumi_Yoshinaga
# 	 https://en.wikipedia.org//wiki/Fumi_Yoshinaga
# ------------------------------
# Iteration: 30
# 	 //en.wikipedia.org/wiki/Wikipedia:Contact_us
# 	 https://en.wikipedia.org///en.wikipedia.org/wiki/Wikipedia:Contact_us
# ------------------------------
# Iteration: 31
# 	 #cite_note-38
# 	 https://en.wikipedia.org/#cite_note-38
# ------------------------------
# Iteration: 32
# 	 /wiki/%C5%8Coku:_The_Inner_Chambers
# 	 https://en.wikipedia.org//wiki/%C5%8Coku:_The_Inner_Chambers
# ------------------------------
# Over!!!!
# 	 https://en.wikipedia.org//wiki/China_Mountain_Zhang
# ------------------------------

# %% [markdown]
# ### DFS

# %%
visited_nodes = []
end_node =_node = 'wiki/Japan'
initial_node = 'wiki/March_Comes_in_like_a_Lion'
dfs_iteratitve(initial_node, visited_nodes, end_node, filters)
